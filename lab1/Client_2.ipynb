# %%
import clientserver

client = clientserver.Client()

client.get("herbert")
# Out:
# 2026-04-14 13:39:34,769 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=62, family=2, type=1, proto=0, laddr=('127.0.0.1', 56502), raddr=('127.0.0.1', 50007)>
# 2026-04-14 13:39:34,770 - vs2lab.a1_layers.clientserver.Client - INFO - Client received answer: 12345678
# '12345678'
