# %% [markdown]
# Importiere Modul

# %%
import clientserver

# %% [markdown]
# Erstelle Client Objekt

# %%
client = clientserver.Client()
# Out:
# 2026-04-16 15:05:05,385 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=55, family=2, type=1, proto=0, laddr=('127.0.0.1', 47550), raddr=('127.0.0.1', 50007)>

# %% [markdown]
# Führe Methoden aus (get)

# %%
client.get("Nutzer0")
client.get("Nutzer1")
client.get("Nutzer2")
client.get("abc")
# Out:
# 2026-04-16 15:05:07,907 - vs2lab.a1_layers.clientserver.Client - INFO - Client received answer: 0
# 2026-04-16 15:05:07,909 - vs2lab.a1_layers.clientserver.Client - INFO - Client received answer: 1
# 2026-04-16 15:05:07,910 - vs2lab.a1_layers.clientserver.Client - INFO - Client received answer: 2
# 2026-04-16 15:05:07,911 - vs2lab.a1_layers.clientserver.Client - INFO - Client received answer: User not found
# 'User not found'

# %% [markdown]
# Führe Methoden aus (getall)

# %%
client.getall()
# Out:
# 2026-04-16 15:05:09,232 - vs2lab.a1_layers.clientserver.Client - INFO - Client received answer: {'Nutzer0': 0, 'Nutzer1': 1, 'Nutzer2': 2, 'Nutzer3': 3, 'Nutzer4': 4, 'Nutzer5': 5, 'Nutzer6': 6, 'Nutzer7': 7, 'Nutzer8': 8, 'Nutzer9': 9, 'Nutzer10': 10, 'Nutzer11': 11, 'Nutzer12': 12, 'Nutzer13': 13, 'Nutzer14': 14, 'Nutzer15': 15, 'Nutzer16': 16, 'Nutzer17': 17, 'Nutzer18': 18, 'Nutzer19': 19, 'Nutzer20': 20, 'Nutzer21': 21, 'Nutzer22': 22, 'Nutzer23': 23, 'Nutzer24': 24, 'Nutzer25': 25, 'Nutzer26': 26, 'Nutzer27': 27, 'Nutzer28': 28, 'Nutzer29': 29, 'Nutzer30': 30, 'Nutzer31': 31, 'Nutzer32': 32, 'Nutzer33': 33, 'Nutzer34': 34, 'Nutzer35': 35, 'Nutzer36': 36, 'Nutzer37': 37, 'Nutzer38': 38, 'Nutzer39': 39, 'Nutzer40': 40, 'Nutzer41': 41, 'Nutzer42': 42, 'Nutzer43': 43, 'Nutzer44': 44, 'Nutzer45': 45, 'Nutzer46': 46, 'Nutzer47': 47, 'Nutzer48': 48, 'Nutzer49': 49, 'Nutzer50': 50, 'Nutzer51': 51, 'Nutzer52': 52, 'Nutzer53': 53, 'Nutzer54': 54, 'Nutzer55': 55, 'Nutzer56': 56, 'Nutzer57
# ...

# %% [markdown]
# Führe Methoden aus (call)

# %%
client.call()
# Out:
# 2026-04-16 15:05:13,755 - vs2lab.a1_layers.clientserver.Client - INFO - Client received answer: Hello, world
# 'Hello, world'

# %% [markdown]
# Schalte Server aus

# %%
client.close()
