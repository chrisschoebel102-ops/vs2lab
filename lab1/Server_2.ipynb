# %% [markdown]
# Importiere Modul

# %%
import clientserver

# %% [markdown]
# erstelle Server Objekt

# %%
server = clientserver.Server()
# Out:
# 2026-04-16 14:18:04,145 - vs2lab.lab1.clientserver.Server - INFO - Server bound to socket <socket.socket fd=45, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>

# %% [markdown]
# starte Server

# %%
server.serve()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 server.serve()
#
# File ~/Desktop/HKA/Semester5/VS2/vs2lab/lab1/clientserver.py:35, in Server.serve(self)
#      32 while self._serving:  # as long as _serving (checked after connections or socket timeouts)
#      33     try:
#      34         # pylint: disable=unused-variable
# ---> 35         (connection, address) = self.sock.accept()  # returns new socket and address of client
#      36         while True:  # forever
#      37             data = connection.recv(1024).decode("ascii")  # receive data from client
#
# File /usr/lib/python3.14/socket.py:298, in socket.accept(self)
#     291 def accept(self):
#     292     """accept() -> (socket object, address info)
#     293
#     294     Wait for an incoming connection.  Return a new socket
# ...
