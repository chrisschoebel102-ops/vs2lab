# %%
import clientserver

server = clientserver.Server()

server.serve()
# Out:
# 2026-04-14 13:39:12,890 - vs2lab.lab1.clientserver.Server - INFO - Server bound to socket <socket.socket fd=65, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 import clientserver
#       2
#       3 server = clientserver.Server()
#       4
# ----> 5 server.serve()
#
# File ~/Desktop/HKA/Semester5/VS2/vs2lab/lab1/clientserver.py:37, in serve(self)
#      35 while True:  # forever
#      36     data = connection.recv(1024).decode("ascii")  # receive data from client
# ---> 37     if not data:
#      38         break  # stop if client stopped
#      40     #-----------#
#
# KeyboardInterrupt:
