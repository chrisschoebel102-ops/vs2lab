# %% [markdown]
# Importiere Modul

# %%
import clientserver

# %% [markdown]
# erstelle Server Objekt

# %%
server = clientserver.Server()
# Out:
# 2026-04-16 15:04:58,643 - vs2lab.lab1.clientserver.Server - INFO - Server bound to socket <socket.socket fd=50, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>

# %% [markdown]
# starte Server

# %%
server.serve()
# Out:
# 2026-04-16 15:05:07,907 - vs2lab.lab1.clientserver.Server - INFO - Server sent message: 0
# 2026-04-16 15:05:07,909 - vs2lab.lab1.clientserver.Server - INFO - Server sent message: 1
# 2026-04-16 15:05:07,910 - vs2lab.lab1.clientserver.Server - INFO - Server sent message: 2
# 2026-04-16 15:05:07,911 - vs2lab.lab1.clientserver.Server - INFO - Server sent message: User not found
# ...
